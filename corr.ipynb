# %%
BoB_altimeter=xr.open_mfdataset('/home/NCAOR/supriyog/raw_data/SL_anomaly/IO_SLA_v2021.nc'
                                ,autoclose=True).sel(latitude=slice(4,25),
                                longitude=slice(78,100)).sla

# %%
BoB_altimeter
# Out:
# <xarray.DataArray 'sla' (time: 9672, latitude: 84, longitude: 88)>
# dask.array<getitem, shape=(9672, 84, 88), dtype=float64, chunksize=(9672, 84, 88), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 1993-01-01 1993-01-02 ... 2019-12-30
#   * longitude  (longitude) float32 78.12 78.38 78.62 78.88 ... 99.38 99.62 99.88
#   * latitude   (latitude) float32 4.125 4.375 4.625 4.875 ... 24.38 24.62 24.88

# %%
BoB_lcs=xr.open_mfdataset('lcs_sla25.nc',autoclose=True).sel(YAXIS=slice(4,25),XAXIS=slice(78,100
                                )).sla_new

# %%
BoB_lcs=xr.open_mfdataset('lcs_sla25_bob.nc',autoclose=True).SLA_NEW
BoB_lcs
# Out:
# <xarray.DataArray 'SLA_NEW' (TIME: 9860, YAXIS: 84, XAXIS: 88)>
# dask.array<open_dataset-890e05e1f7b201a688892775cee95921SLA_NEW, shape=(9860, 84, 88), dtype=float64, chunksize=(9860, 84, 88), chunktype=numpy.ndarray>
# Coordinates:
#   * XAXIS    (XAXIS) float64 78.12 78.38 78.62 78.88 ... 99.12 99.38 99.62 99.88
#   * YAXIS    (YAXIS) float64 4.125 4.375 4.625 4.875 ... 24.12 24.38 24.62 24.88
#   * TIME     (TIME) datetime64[ns] 1993-01-01T12:00:00 ... 2019-12-30T12:00:00
# Attributes:
#     long_name:  SLA[G=MY_GRID,T=01-JAN-1993:31-DEC-2019]
#     history:    From lcs_sla1

# %%
BoB_lcs=BoB_lcs.rename({'YAXIS':'latitude'})
BoB_lcs=BoB_lcs.rename({'XAXIS':'longitude'})
BoB_lcs=BoB_lcs.rename({'TIME':'time'})

# %%
BoB_lcs
# Out:
# <xarray.DataArray 'SLA_NEW' (time: 9860, latitude: 84, longitude: 88)>
# dask.array<open_dataset-890e05e1f7b201a688892775cee95921SLA_NEW, shape=(9860, 84, 88), dtype=float64, chunksize=(9860, 84, 88), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float64 78.12 78.38 78.62 78.88 ... 99.38 99.62 99.88
#   * latitude   (latitude) float64 4.125 4.375 4.625 4.875 ... 24.38 24.62 24.88
#   * time       (time) datetime64[ns] 1993-01-01T12:00:00 ... 2019-12-30T12:00:00
# Attributes:
#     long_name:  SLA[G=MY_GRID,T=01-JAN-1993:31-DEC-2019]
#     history:    From lcs_sla1

# %%
BoB_lcs25=BoB_lcs.interp(latitude=BoB_altimeter.latitude, longitude=BoB_altimeter.longitude)

# %%
BoB_lcs[0].plot()

# %%
corr_data=xr.corr(BoB_lcs,BoB_altimeter,dim='time')

# %%
import xarray as xr

# %%
df=xr.open_mfdataset('subset.nc')

# %%
lon=df.lon.values
lat=df.lat.values

# %%
df['x']=lon[1]
df['y']=lat[0]

# %%
df.surface.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df.surface.plot()
#
# File ~/miniconda3/envs/clim2/lib/python3.10/site-packages/xarray/plot/plot.py:868, in _PlotMethods.__call__(self, **kwargs)
#     867 def __call__(self, **kwargs):
# --> 868     return plot(self._da, **kwargs)
#
# File ~/miniconda3/envs/clim2/lib/python3.10/site-packages/xarray/plot/plot.py:334, in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     330     plotfunc = hist
#     332 kwargs["ax"] = ax
# --> 334 return plotfunc(darray, **kwargs)
#
# ...
